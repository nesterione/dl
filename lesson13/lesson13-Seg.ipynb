# %% [markdown]
# # Lesson 13 Сегментация изображений

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * https://leonardoaraujosantos.gitbooks.io/artificial-inteligence/content/image_segmentation.html
#
# * https://github.com/aurora95/Keras-FCN
